# %%
import polars as pl
import pandas as pd

# %% [markdown]
# # 1 Importing and Previewing Data

# %% [markdown]
# ## .1 Import

# %%
# step: define path to Excel file
pathToData = "Freely_quote_data.xlsx"
dataRaw = pd.read_excel(pathToData, sheet_name="Quotes")
dataDefinitions = pd.read_excel(pathToData, sheet_name="Data Dictionary")

# %% [markdown]
# ## .2 Viewing Definitions and Start of DataFrame

# %%
# step: check definitions
dataDefinitions
# Out:
#                 Column                                              Notes
# 0         destinations  destinations of travel, can be city, country, ...
# 1      trip_start_date                                trip departure date
# 2        trip_end_date                                   trip return date
# 3       traveller_ages  number of travellers and individual traveller(...
# 4    quote_create_time  date and time this quote is generated (between...
# 5          quote_price  total price of the quote inclusive of boosts c...
# 6             platform  web: quote from web get a quote path; qw: quot...
# 7             discount  discount % applied, noting for a quote with 2 ...
# 8         boost_x_name  extra coverage selected, 9 different extra cov...
# 9   boost_x_start_date                          extra coverage start date
# 10    boost_x_end_date                            extra coverage end date
# 11  extra_cancellation  additional cancellation amount for trip costs ...
# 12             convert  YES for a converted quote, NO for an unconvert...

# %%
# step: display data preview
dataRaw.head()
# Out:
#                                         destinations      trip_start_date  \
# 0  Vietnam; Sri Lanka; Portugal; Netherlands; Swi...            30/1/2025
# 1                                        New Zealand  2024-07-10 00:00:00
# 2                              All of Europe; Turkey            14/5/2025
# 3                                                USA  2025-02-01 00:00:00
# 4                                     United Kingdom           30/11/2024
#
#          trip_end_date traveller_ages    quote_create_time  quote_price  \
# 0           16/10/2025   41;40;11;8;5  2024-24-12 13:20:09         1417
# 1           14/10/2024          27;25  2024-10-06 11:47:00           79
# 2  2025-08-06 00:00:00          73;73  2024-11-11 12:13:00          516
# 3            21/1/2025  45;45;14;13;8  2024-12-12 14:32:00          391
# 4  2024-06-12 00:00:00             60  2024-30-11 11:57:29           60
#
#   platform  discount          boost_1_name   boost_1_start_date  ...  \
# 0      web      0.15       Specified Items            30/1/2025  ...
# 1      app      0.15  Adventure Activities  2024-11-10 00:00:00  ...
# 2      web      0.15                   NaN                  NaN  ...
# 3      web      0.15           Snow Sports  2025-05-01 00:00:00  ...
# 4      web      0.10    Extra Cancellation           30/11/2024  ...
#
#   boost_6_start_date boost_6_end_date boost_7_name boost_7_start_date  \
# 0                NaN              NaN          NaN                NaN
# 1                NaN              NaN          NaN                NaN
# 2                NaN              NaN          NaN                NaN
# 3                NaN              NaN          NaN                NaN
# 4                NaN              NaN          NaN                NaN
#
#   boost_7_end_date boost_8_name boost_8_start_date boost_8_end_date  \
# 0              NaN          NaN                NaN              NaN
# 1              NaN          NaN                NaN              NaN
# 2              NaN          NaN                NaN              NaN
# 3              NaN          NaN                NaN              NaN
# 4              NaN          NaN                NaN              NaN
#
#   extra_cancellation convert
# 0                0.0      NO
# 1                0.0     YES
# 2                NaN      NO
# 3            40000.0      NO
# 4             5000.0      NO
#
# [5 rows x 34 columns]

# %% [markdown]
# # 2 Data Manipulation

# %% [markdown]
# ## .1 Creating New Variables

# %% [markdown]
# ### .1 Parsing Traveller Ages into a List

# %%
def _parseAges(ages_str):
    if pd.isna(ages_str):
        return []
    ages_str = str(ages_str)
    if ages_str == '' or ages_str == 'nan':
        return []
    return [int(age) for age in ages_str.split(';') if age.strip()]

dataRaw['travellerAges'] = dataRaw['traveller_ages'].apply(_parseAges)

# %%
dataRaw['travellerAges'].head()
# Out:
# 0     [41, 40, 11, 8, 5]
# 1               [27, 25]
# 2               [73, 73]
# 3    [45, 45, 14, 13, 8]
# 4                   [60]
# Name: travellerAges, dtype: object

# %% [markdown]
# ### .2 Excess Discount
# this calculates the discount over the pre-applied discount that is dependent on the number of travellers
# - 15% for 2 adult travellers
# - 20% for 3+ adult travellers
#
# NOTE: TURNS OUT THIS IS NOT REQUIRED. WE GET NEGATIVE DISCOUNTS

# %%
# dataRaw['excessDiscount'] = dataRaw['discount'] - dataRaw['travellerAges'].apply(
#     lambda ages: 0.20 
#     if 
#         sum(age >=18 for age in ages) >= 3 
#     else 
#         0.15 if sum(age >= 18 for age in ages) == 2 
#     else 
#         0
#     )

# %% [markdown]
# ### .3 Quote Creation Hour and Day of Week

# %%
# step: hour
dataRaw['quoteCreateHour'] = pd.to_datetime(dataRaw['quote_create_time'], format='%Y-%d-%m %H:%M:%S').dt.hour
# step: day of the week
dataRaw['quoteCreateDay'] = pd.to_datetime(dataRaw['quote_create_time'], format='%Y-%d-%m %H:%M:%S').dt.day_name()

# %%
dataRaw[['quoteCreateHour', 'quoteCreateDay']]
# Out:
#        quoteCreateHour quoteCreateDay
# 0                   13        Tuesday
# 1                   11         Sunday
# 2                   12         Monday
# 3                   14       Thursday
# 4                   11       Saturday
# ...                ...            ...
# 69995               22       Thursday
# 69996               13      Wednesday
# 69997                9         Monday
# 69998               13         Friday
# 69999               13         Friday
#
# [70000 rows x 2 columns]

# %% [markdown]
# ### .4 Destination Encoding

# %%
# step: get a count of all destinations
allDestinations = dataRaw['destinations'].str.split(';').explode().str.strip().value_counts()
allDestinations
# Out:
# destinations
# Japan                 7721
# Bali                  5078
# Thailand              4653
# Indonesia             4535
# Domestic Cruise       4208
#                       ...
# Benin                    1
# Burkina Faso             1
# Chad                     1
# Cardiff                  1
# Great Barrier Reef       1
# Name: count, Length: 407, dtype: int64

# %%
# step: get a list of all unique destinations
uniqueDestinations = dataRaw['destinations'].str.split(';').explode().str.strip().unique()
sorted(uniqueDestinations)
# Out:
# ['Abu Dhabi',
#  'Adelaide',
#  'Afghanistan',
#  'Airlie Beach',
#  'Alabama',
#  'Alaska',
#  'Albania',
#  'Alberta',
#  'Algeria',
#  'Alice Springs',
#  'All of Africa',
#  'All of Asia (exclude Nepal)',
#  'All of Europe',
#  'All of Europe (Scandinavia)',
#  'All of North America',
#  'All of South America',
#  'All of South America (Patagonia)',
#  'All of UK',
#  'All of UK (GBR)',
#  'All of UK (Great Britain)',
#  'All of UK (Isle of Man)',
#  'All of UK (United Kingdom)',
#  'All of the Americas',
#  'All of the Americas (Central America)',
#  'All of the Middle East',
#  'All of the Pacific',
#  'All of the Pacific (Pacific Islands)',
#  'America',
#  'American Samoa',
#  'Amsterdam',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antarctica (Cruising)',
#  'Antarctica-Sightseeing Flight',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Arizona',
#  'Armenia',
#  'Aruba',
#  'Athens',
#  'Auckland',
#  'Australia',
#  'Australia (Domestic Cruise)',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bali',
#  'Bangkok',
#  'Bangladesh',
#  'Barbados',
#  'Barcelona',
#  'Beijing',
#  'Belgium',
#  'Belgrade',
#  'Belize',
#  'Benin',
#  'Berlin',
#  'Bermuda',
#  'Bhutan',
#  'Birmingham',
#  'Bolivia',
#  'Bosnia',
#  'Botswana',
#  'Brasilia',
#  'Brazil',
#  'Brisbane',
#  'British Columbia',
#  'Broome',
#  'Brunei',
#  'Brussels',
#  'Budapest',
#  'Buenos Aires',
#  'Bulgaria',
#  'Burkina Faso',
#  'Cairns',
#  'Cairo',
#  'Calgary',
#  'California',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Canary Islands',
#  'Canberra',
#  'Cancun',
#  'Cape Town',
#  'Cape Verde',
#  'Cardiff',
#  'Cayman Islands',
#  'Cebu',
#  'Central African Republic',
#  'Chad',
#  'Chiang Mai',
#  'Chicago',
#  'Chile',
#  'China',
#  'Christchurch',
#  'Cologne',
#  'Colombia',
#  'Colorado',
#  'Connecticut',
#  'Cook Islands',
#  'Copenhagen',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Darwin',
#  'Delhi',
#  'Denmark',
#  'Denpasar',
#  'Dhaka',
#  'Doha',
#  'Domestic Cruise',
#  'Dominica',
#  'Dominican Rep.',
#  'Dubai',
#  'Dublin',
#  'Dubrovnik',
#  'East Timor',
#  'Ecuador',
#  'Edinburgh',
#  'Egypt',
#  'El Salvador',
#  'England',
#  'Eritrea',
#  'Espana',
#  'Estados Unidos',
#  'Estonia',
#  'Ethiopia',
#  'Falkland Islands',
#  'Faroe Islands',
#  'Fiji',
#  'Finland',
#  'Florence',
#  'Florida',
#  'France',
#  'Frankfurt',
#  'Fraser Island',
#  'French Polynesia',
#  'Gambia',
#  'Geneva',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Gibraltar',
#  'Glasglow',
#  'Gold Coast',
#  'Great Barrier Reef',
#  'Greece',
#  'Greenland',
#  'Guadeloupe',
#  'Guatemala',
#  'Guernsey',
#  'Guyana',
#  'Haiti',
#  'Hamilton Island',
#  'Hanoi',
#  'Hawaii',
#  'Helsinki',
#  'Herzegovina',
#  'Ho Chi Minh City',
#  'Hobart',
#  'Holland',
#  'Honduras',
#  'Hong Kong',
#  'Hong Kong (HK)',
#  'Hong Kong (Hongkong)',
#  'Honolulu',
#  'Hungary',
#  'Ibiza',
#  'Iceland',
#  'India',
#  'Indiana',
#  'Indonesia',
#  'Isle of Pines',
#  'Istanbul',
#  'Italy',
#  'Italy (Italia)',
#  'Ivory Coast',
#  'Jakarta',
#  'Jamaica',
#  'Japan',
#  'Jersey',
#  'Johannesburg',
#  'Jordan',
#  'KL',
#  'Kangaroo Island',
#  'Kathmandu',
#  'Kazakhstan',
#  'Kenya',
#  'Koh Samui',
#  'Korea (south)',
#  'Korea (south) (Republic of Korea)',
#  'Korea (south) (South Korea)',
#  'Kosovo',
#  'Kuala Lumpur',
#  'Kuta',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Laos',
#  'Lapland',
#  'Las Vegas',
#  'Latvia',
#  'Lesotho',
#  'Liberia',
#  'Liechtenstein',
#  'Lifou',
#  'Lima',
#  'Lisbon',
#  'Lithuania',
#  'Liverpool',
#  'Lombok',
#  'London',
#  'Lord Howe Island',
#  'Los Angeles',
#  'Loyalty Islands',
#  'Luxembourg',
#  'Lyon',
#  'Macao',
#  'Macau',
#  'Macedonia',
#  'Madagascar',
#  'Madeira',
#  'Madrid',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Malvinas',
#  'Manchester',
#  'Manila',
#  'Marrakech',
#  'Martinique',
#  'Massachusetts',
#  'Mauritius',
#  'Melbourne',
#  'Mexico',
#  'Mexico City',
#  'Miami',
#  'Michigan',
#  'Milan',
#  'Minnesota',
#  'Moldova',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Mumbai',
#  'Munich',
#  'Myanmar (Burma)',
#  'Mystery Island',
#  'Nadi',
#  'Nairobi',
#  'Namibia',
#  'Nauru',
#  'Nebraska',
#  'Nepal',
#  'Netherlands',
#  'Netherlands (The Netherlands)',
#  'Netherlands Antilles',
#  'New Caledonia',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'New Zealand',
#  'New Zealand (NZ)',
#  'Nicaragua',
#  'Nice',
#  'Nigeria',
#  'Noosa',
#  'Norfolk Island',
#  'North Carolina',
#  'Northern Ireland',
#  'Northern Territory',
#  'Norway',
#  'Noumea',
#  'Nova Scotia',
#  'Nuremburg',
#  'Oman',
#  'Oregon',
#  'Osaka',
#  'Ottawa',
#  'Pakistan',
#  'Palau',
#  'Panama',
#  'Panama City',
#  'Papua New Guinea',
#  'Papua New Guinea (PNG)',
#  'Paraguay',
#  'Paris',
#  'Pattaya',
#  'Penang',
#  'Perth',
#  'Peru',
#  'Philippines',
#  'Phuket',
#  'Poland',
#  'Port Douglas',
#  'Port Vila',
#  'Port Villa',
#  'Portugal',
#  'Prague',
#  'Puerto Rico',
#  'Qatar',
#  'Quebec',
#  'Queensland',
#  'Queenstown',
#  'Rarotonga',
#  'Republic of Ireland',
#  'Reunion',
#  'Rio de Janeiro',
#  'Romania',
#  'Rome',
#  'Rwanda',
#  'Salvador',
#  'Salzburg',
#  'Samoa',
#  'San Francisco',
#  'San Marino',
#  'Santiago',
#  'Sapporo',
#  'Saudi Arabia',
#  'Scotland',
#  'Senegal',
#  'Seoul',
#  'Serbia',
#  'Seychelles',
#  'Shanghai',
#  'Shenzhen',
#  'Siem Reap',
#  'Sierra Leone',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Solomon Islands',
#  'South Africa',
#  'South Australia',
#  'South Sudan',
#  'South West Pacific Cruise',
#  'Spain',
#  'Sri Lanka',
#  'Sri Lanka (SriLanka)',
#  'St. Kitts-Nevis',
#  'St. Lucia',
#  'Stockholm',
#  'Strasbourg',
#  'Sunshine Coast',
#  'Suva',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Sydney',
#  'Tahiti',
#  'Taipei',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Tasmania',
#  'Tenerife',
#  'Tennessee',
#  'Texas',
#  'Thailand',
#  'Tibet',
#  'Timor-Leste',
#  'Togo',
#  'Tokyo',
#  'Tonga',
#  'Toronto',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'USA',
#  'Ubud',
#  'Uganda',
#  'Uluru',
#  'United Arab Emirates',
#  'United Arab Emirates (U.A.E.)',
#  'United Arab Emirates (UAE)',
#  'United Kingdom',
#  'United States of America',
#  'Uruguay',
#  'Utah',
#  'Uzbekistan',
#  'Vancouver',
#  'Vanuatu',
#  'Vatican City',
#  'Venezuela',
#  'Venice',
#  'Vienna',
#  'Vietnam',
#  'Virgin Islands',
#  'Virginia',
#  'Wales',
#  'Western Australia',
#  'Western Samoa',
#  'Whitsundays',
#  'Worldwide',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe',
#  'Zurich']
